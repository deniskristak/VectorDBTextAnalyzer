# %%
import ast
from vector_db import VectorDBTextAnalyzerBase

# %%
import ast

class DocStringExtractor(ast.NodeVisitor):
    def __init__(self):
        self.all_docstrings = []
        self.current_class_name = None

    def visit_ClassDef(self, node):
        self.current_class_name = node.name
        self.generic_visit(node)
        self.current_class_name = None

    def visit_FunctionDef(self, node):
        self._extract_info(node)

    def visit_AsyncFunctionDef(self, node):
        self._extract_info(node)

    def _extract_info(self, node):
        # Determine if it's a method in a class or a standalone function
        full_name = f"{self.current_class_name}.{node.name}" if self.current_class_name else node.name
        docstring = ast.get_docstring(node)

        # Extract function/method arguments
        args = [arg.arg for arg in node.args.args]

        # Prepare the info dictionary
        info = {
            "unique_identifier": full_name,
            "arguments": args,
            "text": f"{full_name}({', '.join(args)}):\n{docstring}" if docstring else f"{full_name}({', '.join(args)})"
        }
        self.all_docstrings.append(info)

        self.generic_visit(node)

def extract_docstrings(filename):
    with open(filename, "r") as source:
        tree = ast.parse(source.read(), filename=filename)

    docstring_extractor = DocStringExtractor()
    docstring_extractor.visit(tree)
    return docstring_extractor.all_docstrings

# Example usage
# Assuming `filename` is the path to the Python file you want to analyze
# docstrings = extract_docstrings(filename)
# for doc in docstrings:
#     print(doc)

# %%
def extract_python_files_in_folder(folder):
    import os
    python_files = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            if file.endswith(".py"):
                python_files.append(os.path.join(root, file))
    return python_files

# %%
# taken from easybuild-framework
folder_name = "framework"
python_files = extract_python_files_in_folder(folder_name)
for f in python_files:
    print(f)
# Out:
# framework/easyblock.py
# framework/extensioneasyblock.py
# framework/easystack.py
# framework/__init__.py
# framework/extension.py
# framework/easyconfig/style.py
# framework/easyconfig/tools.py
# framework/easyconfig/constants.py
# framework/easyconfig/__init__.py
# framework/easyconfig/types.py
# framework/easyconfig/parser.py
# framework/easyconfig/templates.py
# framework/easyconfig/default.py
# framework/easyconfig/tweak.py
# framework/easyconfig/licenses.py
# framework/easyconfig/easyconfig.py
# framework/easyconfig/format/pyheaderconfigobj.py
# framework/easyconfig/format/one.py
# framework/easyconfig/format/version.py
# framework/easyconfig/format/convert.py
# framework/easyconfig/format/__init__.py
# framework/easyconfig/format/two.py
# framework/easyconfig/format/format.py
# framework/easyconfig/format/yeb.py

# %%
# docstrings = extract_docstrings("vector_db.py")

docstrings = []
for f in python_files:
    docstrings.extend(extract_docstrings(f))

for d in docstrings:
    print(d)
# Out:
# {'unique_identifier': 'EasyBlock.extra_options', 'arguments': ['extra'], 'text': 'EasyBlock.extra_options(extra):\nExtra options method which will be passed to the EasyConfig constructor.'}
# {'unique_identifier': 'EasyBlock.__init__', 'arguments': ['self', 'ec'], 'text': 'EasyBlock.__init__(self, ec):\nInitialize the EasyBlock instance.\n:param ec: a parsed easyconfig file (EasyConfig instance)'}
# {'unique_identifier': 'EasyBlock.post_init', 'arguments': ['self'], 'text': 'EasyBlock.post_init(self):\nRun post-initialization tasks.'}
# {'unique_identifier': 'EasyBlock._init_log', 'arguments': ['self'], 'text': 'EasyBlock._init_log(self):\nInitialize the logger.'}
# {'unique_identifier': 'EasyBlock.close_log', 'arguments': ['self'], 'text': 'EasyBlock.close_log(self):\nShutdown the logger.'}
# {'unique_identifier': 'EasyBlock.init_dry_run', 'arguments': ['self'], 'text': 'EasyBlock.init_dry_run(self):\nInitialise easyblock instance for performing a dry run.'}
# {'unique_identifier': 'EasyBlock.dry_run_msg', 'arguments': ['self', 'msg'], 'text': 'EasyBlock.dry_run_msg(self, msg):\nPrint dry run message.'}
# {'unique_identifier': 'EasyBlock.get_checksum_for', 'arguments': ['self', 'checksums', 'filename', 'index'], 'text': 'EasyBlock.get_checksum_for(self, checksums, filename, index):\nObtain checksum for given filename.\n\n:param checksums: a list or tuple of checksums (or None)\n:param filename: name of the file to obtain checksum for\n:param index: index of file in list'}
# {'unique_identifier': 'EasyBlock.get_checksums_from_json', 'arguments': ['self', 'always_read'], 'text': 'EasyBlock.get_checksums_from_json(self, always_read):\nGet checksums for this software that are provided in a checksums.json file\n\n:param always_read: always read the checksums.json file, even if it has been read before'}
# {'unique_identifier': 'EasyBlock.fetch_source', 'arguments': ['self', 'source', 'checksum', 'extension', 'download_instructions'], 'text': "EasyBlock.fetch_source(self, source, checksum, extension, download_instructions):\nGet a specific source (tarball, iso, url)\nWill be tested for existence or can be located\n\n:param source: source to be found (single dictionary in 'sources' list, or filename)\n:param checksum: checksum corresponding to source\n:param extension: flag if being called from collect_exts_file_info()"}
# {'unique_identifier': 'EasyBlock.fetch_sources', 'arguments': ['self', 'sources', 'checksums'], 'text': "EasyBlock.fetch_sources(self, sources, checksums):\nAdd a list of source files (can be tarballs, isos, urls).\nAll source files will be checked if a file exists (or can be located)\n\n:param sources: list of sources to fetch (if None, use 'sources' easyconfig parameter)\n:param checksums: list of checksums for sources"}
# {'unique_identifier': 'EasyBlock.fetch_patches', 'arguments': ['self', 'patch_specs', 'extension', 'checksums'], 'text': 'EasyBlock.fetch_patches(self, patch_specs, extension, checksums):\nAdd a list of patches.\nAll patches will be checked if a file exists (or can be located)'}
# {'unique_identifier': 'EasyBlock.fetch_extension_sources', 'arguments': ['self', 'skip_checksums'], 'text': 'EasyBlock.fetch_extension_sources(self, skip_checksums):\nFetch source and patch files for extensions (DEPRECATED, use collect_exts_file_info instead).'}
# {'unique_identifier': 'EasyBlock.collect_exts_file_info', 'arguments': ['self', 'fetch_files', 'verify_checksums'], 'text': 'EasyBlock.collect_exts_file_info(self, fetch_files, verify_checksums):\nCollect information on source and patch files for extensions.\n\n:param fetch_files: whether or not to fetch files (if False, path to files will be missing from info)\n:param verify_checksums: whether or not to verify checksums\n:return: list of dict values, one per extension, with information on source/patch files.'}
# {'unique_identifier': 'EasyBlock.obtain_file', 'arguments': ['self', 'filename', 'extension', 'urls', 'download_filename', 'force_download', 'git_config', 'no_download', 'download_instructions', 'alt_location', 'warning_only'], 'text': 'EasyBlock.obtain_file(self, filename, extension, urls, download_filename, force_download, git_config, no_download, download_instructions, alt_location, warning_only):\nLocate the file with the given name\n- searches in different subdirectories of source path\n- supports fetching file from the web if path is specified as an url (i.e. starts with "http://:")\n:param filename: filename of source\n:param extension: indicates whether locations for extension sources should also be considered\n:param urls: list of source URLs where this file may be available\n:param download_filename: filename with which the file should be downloaded, and then renamed to <filename>\n:param force_download: always try to download file, even if it\'s already available in source path\n:param git_config: dictionary to define how to download a git repository\n:param no_download: do not try to download the file\n:param download_instructions: instructions to manually add source (used for complex cases)\n:param alt_location: alternative location to use instead of self.name'}
# {'unique_identifier': 'EasyBlock.name', 'arguments': ['self'], 'text': 'EasyBlock.name(self):\nShortcut the get the module name.'}
# {'unique_identifier': 'EasyBlock.version', 'arguments': ['self'], 'text': 'EasyBlock.version(self):\nShortcut the get the module version.'}
# {'unique_identifier': 'EasyBlock.toolchain', 'arguments': ['self'], 'text': 'EasyBlock.toolchain(self):\nToolchain used to build this easyblock'}
# {'unique_identifier': 'EasyBlock.full_mod_name', 'arguments': ['self'], 'text': 'EasyBlock.full_mod_name(self):\nFull module name (including subdirectory in module install path)'}
# {'unique_identifier': 'EasyBlock.short_mod_name', 'arguments': ['self'], 'text': 'EasyBlock.short_mod_name(self):\nShort module name (not including subdirectory in module install path)'}
# {'unique_identifier': 'EasyBlock.mod_subdir', 'arguments': ['self'], 'text': 'EasyBlock.mod_subdir(self):\nSubdirectory in module install path'}
# {'unique_identifier': 'EasyBlock.moduleGenerator', 'arguments': ['self'], 'text': 'EasyBlock.moduleGenerator(self):\nModule generator (DEPRECATED, use self.module_generator instead).'}
# {'unique_identifier': 'EasyBlock.gen_builddir', 'arguments': ['self'], 'text': 'EasyBlock.gen_builddir(self):\nGenerate the (unique) name for the builddir'}
# {'unique_identifier': 'EasyBlock.make_builddir', 'arguments': ['self'], 'text': 'EasyBlock.make_builddir(self):\nCreate the build directory.'}
# {'unique_identifier': 'EasyBlock.reset_env', 'arguments': ['self'], 'text': 'EasyBlock.reset_env(self):\nReset environment.\nWhen iterating over builddependencies, every time we start a new iteration\nwe need to restore the environment to where it was before the relevant modules\nwere loaded.'}
# {'unique_identifier': 'EasyBlock.gen_installdir', 'arguments': ['self'], 'text': 'EasyBlock.gen_installdir(self):\nGenerate the name of the installation directory.'}
# {'unique_identifier': 'EasyBlock.make_installdir', 'arguments': ['self', 'dontcreate'], 'text': 'EasyBlock.make_installdir(self, dontcreate):\nCreate the installation directory.'}
# {'unique_identifier': 'EasyBlock.make_dir', 'arguments': ['self', 'dir_name', 'clean', 'dontcreateinstalldir'], 'text': 'EasyBlock.make_dir(self, dir_name, clean, dontcreateinstalldir):\nCreate the directory.'}
# {'unique_identifier': 'EasyBlock.set_up_cuda_cache', 'arguments': ['self'], 'text': 'EasyBlock.set_up_cuda_cache(self):\nSet up CUDA PTX cache.'}
# {'unique_identifier': 'EasyBlock.make_devel_module', 'arguments': ['self', 'create_in_builddir'], 'text': 'EasyBlock.make_devel_module(self, create_in_builddir):\nCreate a develop module file which sets environment based on the build\nUsage: module load name, which loads the module you want to use. $EBDEVELNAME should then be the full path\nto the devel module file. So now you can module load $EBDEVELNAME.\n\nWARNING: you cannot unload using $EBDEVELNAME (for now: use module unload `basename $EBDEVELNAME`)'}
# {'unique_identifier': 'EasyBlock.make_module_deppaths', 'arguments': ['self'], 'text': "EasyBlock.make_module_deppaths(self):\nAdd specific 'module use' actions to module file, in order to find\ndependencies outside the end user's MODULEPATH."}
# {'unique_identifier': 'EasyBlock.make_module_dep', 'arguments': ['self', 'unload_info'], 'text': 'EasyBlock.make_module_dep(self, unload_info):\nMake the dependencies for the module file.\n\n:param unload_info: dictionary with full module names as keys and module name to unload first as corr. value'}
# {'unique_identifier': 'EasyBlock.make_module_description', 'arguments': ['self'], 'text': 'EasyBlock.make_module_description(self):\nCreate the module description.'}
# {'unique_identifier': 'EasyBlock.make_module_extra', 'arguments': ['self', 'altroot', 'altversion'], 'text': 'EasyBlock.make_module_extra(self, altroot, altversion):\nSet extra stuff in module file, e.g. $EBROOT*, $EBVERSION*, etc.\n\n:param altroot: path to use to define $EBROOT*\n:param altversion: version to use to define $EBVERSION*'}
# {'unique_identifier': 'EasyBlock.make_module_extra_extensions', 'arguments': ['self'], 'text': 'EasyBlock.make_module_extra_extensions(self):\nSets optional variables for extensions.'}
# {'unique_identifier': 'EasyBlock.make_module_footer', 'arguments': ['self'], 'text': 'EasyBlock.make_module_footer(self):\nInsert a footer section in the module file, primarily meant for contextual information'}
# {'unique_identifier': 'EasyBlock.make_module_extend_modpath', 'arguments': ['self'], 'text': 'EasyBlock.make_module_extend_modpath(self):\nInclude prepend-path statements for extending $MODULEPATH.'}
# {'unique_identifier': 'EasyBlock.make_module_group_check', 'arguments': ['self'], 'text': 'EasyBlock.make_module_group_check(self):\nCreate the necessary group check.'}
# {'unique_identifier': 'EasyBlock.make_module_req', 'arguments': ['self'], 'text': 'EasyBlock.make_module_req(self):\nGenerate the environment-variables to run the module.'}
# {'unique_identifier': 'EasyBlock.make_module_req_guess', 'arguments': ['self'], 'text': 'EasyBlock.make_module_req_guess(self):\nA dictionary of possible directories to look for.'}
# {'unique_identifier': 'EasyBlock.load_module', 'arguments': ['self', 'mod_paths', 'purge', 'extra_modules', 'verbose'], 'text': "EasyBlock.load_module(self, mod_paths, purge, extra_modules, verbose):\nLoad module for this software package/version, after purging all currently loaded modules.\n\n:param mod_paths: list of (additional) module paths to take into account\n:param purge: boolean indicating whether or not to purge currently loaded modules first\n:param extra_modules: list of extra modules to load (these are loaded *before* loading the 'self' module)\n:param verbose: print modules being loaded when trace mode is enabled"}
# {'unique_identifier': 'EasyBlock.load_fake_module', 'arguments': ['self', 'purge', 'extra_modules', 'verbose'], 'text': "EasyBlock.load_fake_module(self, purge, extra_modules, verbose):\nCreate and load fake module.\n\n:param purge: boolean indicating whether or not to purge currently loaded modules first\n:param extra_modules: list of extra modules to load (these are loaded *before* loading the 'self' module)"}
# {'unique_identifier': 'EasyBlock.clean_up_fake_module', 'arguments': ['self', 'fake_mod_data'], 'text': 'EasyBlock.clean_up_fake_module(self, fake_mod_data):\nClean up fake module.'}
# {'unique_identifier': 'EasyBlock.load_dependency_modules', 'arguments': ['self'], 'text': 'EasyBlock.load_dependency_modules(self):\nLoad dependency modules.'}
# {'unique_identifier': 'EasyBlock._make_extension_list', 'arguments': ['self'], 'text': 'EasyBlock._make_extension_list(self):\nReturn a list of extension names and their versions included in this installation\n\nEach entry should be a (name, version) tuple or just (name, ) if no version exists'}
# {'unique_identifier': 'EasyBlock.make_extension_string', 'arguments': ['self', 'name_version_sep', 'ext_sep', 'sort'], 'text': 'EasyBlock.make_extension_string(self, name_version_sep, ext_sep, sort):\nGenerate a string with a list of extensions.\n\nThe name and version are separated by name_version_sep and each extension is separated by ext_sep'}
# {'unique_identifier': 'EasyBlock.prepare_for_extensions', 'arguments': ['self'], 'text': 'EasyBlock.prepare_for_extensions(self):\nAlso do this before (eg to set the template)'}
# {'unique_identifier': 'EasyBlock.skip_extensions', 'arguments': ['self'], 'text': 'EasyBlock.skip_extensions(self):\nSkip already installed extensions,\nby removing them from list of Extension instances to install (self.ext_instances).\n\nThis is done in parallel when EasyBuild is configured to install extensions in parallel.'}
# {'unique_identifier': 'EasyBlock.skip_extensions_sequential', 'arguments': ['self', 'exts_filter'], 'text': 'EasyBlock.skip_extensions_sequential(self, exts_filter):\nSkip already installed extensions (checking sequentially),\nby removing them from list of Extension instances to install (self.ext_instances).'}
# {'unique_identifier': 'EasyBlock.skip_extensions_parallel', 'arguments': ['self', 'exts_filter'], 'text': 'EasyBlock.skip_extensions_parallel(self, exts_filter):\nSkip already installed extensions (checking in parallel),\nby removing them from list of Extension instances to install (self.ext_instances).'}
# {'unique_identifier': 'EasyBlock.install_extensions', 'arguments': ['self', 'install'], 'text': "EasyBlock.install_extensions(self, install):\nInstall extensions.\n\n:param install: actually install extensions, don't just prepare environment for installing"}
# {'unique_identifier': 'EasyBlock.install_extensions_sequential', 'arguments': ['self', 'install'], 'text': "EasyBlock.install_extensions_sequential(self, install):\nInstall extensions sequentially.\n\n:param install: actually install extensions, don't just prepare environment for installing"}
# {'unique_identifier': 'EasyBlock.install_extensions_parallel', 'arguments': ['self', 'install'], 'text': "EasyBlock.install_extensions_parallel(self, install):\nInstall extensions in parallel.\n\n:param install: actually install extensions, don't just prepare environment for installing"}
# {'unique_identifier': 'EasyBlock.update_exts_progress_bar_helper', 'arguments': ['running_exts', 'progress_size'], 'text': 'EasyBlock.update_exts_progress_bar_helper(running_exts, progress_size):\nHelper function to update extensions progress bar.'}
# {'unique_identifier': 'EasyBlock.start_dir', 'arguments': ['self'], 'text': 'EasyBlock.start_dir(self):\nStart directory in build directory'}
# {'unique_identifier': 'EasyBlock.guess_start_dir', 'arguments': ['self'], 'text': "EasyBlock.guess_start_dir(self):\nReturn the directory where to start the whole configure/make/make install cycle from\n- typically self.src[0]['finalpath']\n- start_dir option\n-- if abspath: use that\n-- else, treat it as subdir for regular procedure"}
# {'unique_identifier': 'EasyBlock.check_accepted_eula', 'arguments': ['self', 'name', 'more_info'], 'text': 'EasyBlock.check_accepted_eula(self, name, more_info):\nCheck whether EULA for this software is accepted in current EasyBuild configuration.'}
# {'unique_identifier': 'EasyBlock.handle_iterate_opts', 'arguments': ['self'], 'text': 'EasyBlock.handle_iterate_opts(self):\nHandle options relevant during iterated part of build/install procedure.'}
# {'unique_identifier': 'EasyBlock.post_iter_step', 'arguments': ['self'], 'text': 'EasyBlock.post_iter_step(self):\nRestore options that were iterated over'}
# {'unique_identifier': 'EasyBlock.det_iter_cnt', 'arguments': ['self'], 'text': 'EasyBlock.det_iter_cnt(self):\nDetermine iteration count based on configure/build/install options that may be lists.'}
# {'unique_identifier': 'EasyBlock.set_parallel', 'arguments': ['self'], 'text': "EasyBlock.set_parallel(self):\nSet 'parallel' easyconfig parameter to determine how many cores can/should be used for parallel builds."}
# {'unique_identifier': 'EasyBlock.remove_module_file', 'arguments': ['self'], 'text': 'EasyBlock.remove_module_file(self):\nRemove module file (if it exists), and check for ghost installation directory (and deal with it).'}
# {'unique_identifier': 'EasyBlock.report_test_failure', 'arguments': ['self', 'msg_or_error'], 'text': 'EasyBlock.report_test_failure(self, msg_or_error):\nReport a failing test either via an exception or warning depending on ignore-test-failure\n\n:param msg_or_error: failure description (string value or an EasyBuildError instance)'}
# {'unique_identifier': 'EasyBlock.check_readiness_step', 'arguments': ['self'], 'text': 'EasyBlock.check_readiness_step(self):\nVerify if all is ok to start build.'}
# {'unique_identifier': 'EasyBlock.fetch_step', 'arguments': ['self', 'skip_checksums'], 'text': 'EasyBlock.fetch_step(self, skip_checksums):\nFetch source files and patches (incl. extensions).'}
# {'unique_identifier': 'EasyBlock.checksum_step', 'arguments': ['self'], 'text': 'EasyBlock.checksum_step(self):\nVerify checksum of sources and patches, if a checksum is available.'}
# {'unique_identifier': 'EasyBlock.check_checksums_for', 'arguments': ['self', 'ent', 'sub', 'source_cnt'], 'text': 'EasyBlock.check_checksums_for(self, ent, sub, source_cnt):\nUtility method: check whether SHA256 checksums for all sources/patches are available, for given entity'}
# {'unique_identifier': 'EasyBlock.check_checksums', 'arguments': ['self'], 'text': 'EasyBlock.check_checksums(self):\nCheck whether a SHA256 checksum is available for all sources & patches (incl. extensions).\n\n:return: list of strings describing checksum issues (missing checksums, wrong checksum type, etc.)'}
# {'unique_identifier': 'EasyBlock.extract_step', 'arguments': ['self'], 'text': 'EasyBlock.extract_step(self):\nUnpack the source files.'}
# {'unique_identifier': 'EasyBlock.patch_step', 'arguments': ['self', 'beginpath', 'patches'], 'text': 'EasyBlock.patch_step(self, beginpath, patches):\nApply the patches'}
# {'unique_identifier': 'EasyBlock.prepare_step', 'arguments': ['self', 'start_dir', 'load_tc_deps_modules'], 'text': "EasyBlock.prepare_step(self, start_dir, load_tc_deps_modules):\nPre-configure step. Set's up the builddir just before starting configure\n\n:param start_dir: guess start directory based on unpacked sources\n:param load_tc_deps_modules: load modules for toolchain and dependencies in build environment"}
# {'unique_identifier': 'EasyBlock.configure_step', 'arguments': ['self'], 'text': 'EasyBlock.configure_step(self):\nConfigure build  (abstract method).'}
# {'unique_identifier': 'EasyBlock.build_step', 'arguments': ['self'], 'text': 'EasyBlock.build_step(self):\nBuild software  (abstract method).'}
# {'unique_identifier': 'EasyBlock.test_step', 'arguments': ['self'], 'text': 'EasyBlock.test_step(self):\nRun unit tests provided by software (if any).'}
# {'unique_identifier': 'EasyBlock._test_step', 'arguments': ['self'], 'text': 'EasyBlock._test_step(self):\nRun the test_step and handles failures'}
# {'unique_identifier': 'EasyBlock.stage_install_step', 'arguments': ['self'], 'text': 'EasyBlock.stage_install_step(self):\nInstall in a stage directory before actual installation.'}
# {'unique_identifier': 'EasyBlock.install_step', 'arguments': ['self'], 'text': 'EasyBlock.install_step(self):\nInstall built software (abstract method).'}
# {'unique_identifier': 'EasyBlock.init_ext_instances', 'arguments': ['self'], 'text': 'EasyBlock.init_ext_instances(self):\nCreate class instances for all extensions.'}
# {'unique_identifier': 'EasyBlock.update_exts_progress_bar', 'arguments': ['self', 'info', 'progress_size', 'total'], 'text': 'EasyBlock.update_exts_progress_bar(self, info, progress_size, total):\nUpdate extensions progress bar with specified info and amount of progress made'}
# {'unique_identifier': 'EasyBlock.extensions_step', 'arguments': ['self', 'fetch', 'install'], 'text': "EasyBlock.extensions_step(self, fetch, install):\nAfter make install, run this.\n- only if variable len(exts_list) > 0\n- optionally: load module that was just created using temp module file\n- find source for extensions, in 'extensions' (and 'packages' for legacy reasons)\n- run extra_extensions"}
# {'unique_identifier': 'EasyBlock.package_step', 'arguments': ['self'], 'text': 'EasyBlock.package_step(self):\nPackage installed software (e.g., into an RPM), if requested, using selected package tool.'}
# {'unique_identifier': 'EasyBlock.fix_shebang', 'arguments': ['self'], 'text': 'EasyBlock.fix_shebang(self):\nFix shebang lines for specified files.'}
# {'unique_identifier': 'EasyBlock.run_post_install_commands', 'arguments': ['self', 'commands'], 'text': "EasyBlock.run_post_install_commands(self, commands):\nRun post install commands that are specified via 'postinstallcmds' easyconfig parameter."}
# {'unique_identifier': 'EasyBlock.apply_post_install_patches', 'arguments': ['self', 'patches'], 'text': "EasyBlock.apply_post_install_patches(self, patches):\nApply post-install patch files that are specified via the 'postinstallpatches' easyconfig parameter."}
# {'unique_identifier': 'EasyBlock.print_post_install_messages', 'arguments': ['self'], 'text': "EasyBlock.print_post_install_messages(self):\nPrint post-install messages that are specified via the 'postinstallmsgs' easyconfig parameter."}
# {'unique_identifier': 'EasyBlock.post_install_step', 'arguments': ['self'], 'text': 'EasyBlock.post_install_step(self):\nDo some postprocessing\n- run post install commands if any were specified'}
# {'unique_identifier': 'EasyBlock.sanity_check_step', 'arguments': ['self'], 'text': 'EasyBlock.sanity_check_step(self):\nDo a sanity check on the installation\n- if *any* of the files/subdirectories in the installation directory listed\n  in sanity_check_paths are non-existent (or empty), the sanity check fails'}
# {'unique_identifier': 'EasyBlock._sanity_check_step_multi_deps', 'arguments': ['self'], 'text': 'EasyBlock._sanity_check_step_multi_deps(self):\nPerform sanity check for installations that iterate over a list a versions for particular dependencies.'}
# {'unique_identifier': 'EasyBlock.sanity_check_rpath', 'arguments': ['self', 'rpath_dirs', 'check_readelf_rpath'], 'text': 'EasyBlock.sanity_check_rpath(self, rpath_dirs, check_readelf_rpath):\nSanity check binaries/libraries w.r.t. RPATH linking.'}
# {'unique_identifier': 'EasyBlock.bin_lib_subdirs', 'arguments': ['self'], 'text': 'EasyBlock.bin_lib_subdirs(self):\nList of subdirectories for binaries and libraries for this software installation.\nThis is used during the sanity check to check RPATH linking and banned/required linked shared libraries.'}
# {'unique_identifier': 'EasyBlock.banned_linked_shared_libs', 'arguments': ['self'], 'text': "EasyBlock.banned_linked_shared_libs(self):\nList of shared libraries which are not allowed to be linked in any installed binary/library.\nSupported values are pure library names without 'lib' prefix or extension ('example'),\nfile names ('libexample.so'), and full paths ('/usr/lib64/libexample.so')."}
# {'unique_identifier': 'EasyBlock.required_linked_shared_libs', 'arguments': ['self'], 'text': "EasyBlock.required_linked_shared_libs(self):\nList of shared libraries which must be linked in all installed binaries/libraries.\nSupported values are pure library names without 'lib' prefix or extension ('example'),\nfile names ('libexample.so'), and full paths ('/usr/lib64/libexample.so')."}
# {'unique_identifier': 'EasyBlock.sanity_check_linked_shared_libs', 'arguments': ['self', 'subdirs'], 'text': 'EasyBlock.sanity_check_linked_shared_libs(self, subdirs):\nCheck whether specific shared libraries are (not) linked into installed binaries/libraries.'}
# {'unique_identifier': 'EasyBlock.regex_for_lib', 'arguments': ['lib'], 'text': 'EasyBlock.regex_for_lib(lib):\nCompose regular expression for specified banned/required library.'}
# {'unique_identifier': 'EasyBlock._sanity_check_step_common', 'arguments': ['self', 'custom_paths', 'custom_commands'], 'text': 'EasyBlock._sanity_check_step_common(self, custom_paths, custom_commands):\nDetermine sanity check paths and commands to use.\n\n:param custom_paths: custom sanity check paths to check existence for\n:param custom_commands: custom sanity check commands to run'}
# {'unique_identifier': 'EasyBlock._sanity_check_step_dry_run', 'arguments': ['self', 'custom_paths', 'custom_commands'], 'text': 'EasyBlock._sanity_check_step_dry_run(self, custom_paths, custom_commands):\nDry run version of sanity_check_step method.\n\n:param custom_paths: custom sanity check paths to check existence for\n:param custom_commands: custom sanity check commands to run'}
# {'unique_identifier': 'EasyBlock._sanity_check_step_extensions', 'arguments': ['self'], 'text': 'EasyBlock._sanity_check_step_extensions(self):\nSanity check on extensions (if any).'}
# {'unique_identifier': 'EasyBlock.sanity_check_load_module', 'arguments': ['self', 'extension', 'extra_modules'], 'text': 'EasyBlock.sanity_check_load_module(self, extension, extra_modules):\nLoad module to prepare environment for sanity check'}
# {'unique_identifier': 'EasyBlock._sanity_check_step', 'arguments': ['self', 'custom_paths', 'custom_commands', 'extension', 'extra_modules'], 'text': 'EasyBlock._sanity_check_step(self, custom_paths, custom_commands, extension, extra_modules):\nReal version of sanity_check_step method.\n\n:param custom_paths: custom sanity check paths to check existence for\n:param custom_commands: custom sanity check commands to run\n:param extension: indicates whether or not sanity check is run for an extension\n:param extra_modules: extra modules to load before running sanity check commands'}
# {'unique_identifier': 'EasyBlock.check_path', 'arguments': ['xs', 'typ', 'check_fn'], 'text': 'EasyBlock.check_path(xs, typ, check_fn):\nSanity check for one particular path.'}
# {'unique_identifier': 'EasyBlock.xs2str', 'arguments': ['xs'], 'text': 'EasyBlock.xs2str(xs):\nHuman-readable version of alternative locations for a particular file/directory.'}
# {'unique_identifier': 'EasyBlock._set_module_as_default', 'arguments': ['self', 'fake'], 'text': "EasyBlock._set_module_as_default(self, fake):\nSets the default module version except if we are in dry run\n\n:param fake: set default for 'fake' module in temporary location"}
# {'unique_identifier': 'EasyBlock.cleanup_step', 'arguments': ['self'], 'text': "EasyBlock.cleanup_step(self):\nCleanup leftover mess: remove/clean build directory\n\nexcept when we're building in the installation directory or\ncleanup_builddir is False, otherwise we remove the installation"}
# {'unique_identifier': 'EasyBlock.invalidate_module_caches', 'arguments': ['self', 'modpath'], 'text': 'EasyBlock.invalidate_module_caches(self, modpath):\nHelper method to invalidate module caches for specified module path.'}
# {'unique_identifier': 'EasyBlock.make_module_step', 'arguments': ['self', 'fake'], 'text': "EasyBlock.make_module_step(self, fake):\nGenerate module file\n\n:param fake: generate 'fake' module in temporary location, rather than actual module file"}
# {'unique_identifier': 'EasyBlock.permissions_step', 'arguments': ['self'], 'text': 'EasyBlock.permissions_step(self):\nFinalize installation procedure: adjust permissions as configured, change group ownership (if requested).\nInstalling user must be member of the group that it is changed to.'}
# {'unique_identifier': 'EasyBlock.test_cases_step', 'arguments': ['self'], 'text': 'EasyBlock.test_cases_step(self):\nRun provided test cases.'}
# {'unique_identifier': 'EasyBlock.update_config_template_run_step', 'arguments': ['self'], 'text': 'EasyBlock.update_config_template_run_step(self):\nUpdate the the easyconfig template dictionary with easyconfig.TEMPLATE_NAMES_EASYBLOCK_RUN_STEP names'}
# {'unique_identifier': 'EasyBlock.skip_step', 'arguments': ['self', 'step', 'skippable'], 'text': 'EasyBlock.skip_step(self, step, skippable):\nDedice whether or not to skip the specified step.'}
# {'unique_identifier': 'EasyBlock.run_step', 'arguments': ['self', 'step', 'step_methods'], 'text': 'EasyBlock.run_step(self, step, step_methods):\nRun step, returns false when execution should be stopped'}
# {'unique_identifier': 'EasyBlock.get_steps', 'arguments': ['run_test_cases', 'iteration_count'], 'text': 'EasyBlock.get_steps(run_test_cases, iteration_count):\nReturn a list of all steps to be performed.'}
# {'unique_identifier': 'EasyBlock.get_step', 'arguments': ['tag', 'descr', 'substeps', 'skippable', 'initial'], 'text': "EasyBlock.get_step(tag, descr, substeps, skippable, initial):\nDetermine step definition based on whether it's an initial run or not."}
# {'unique_identifier': 'EasyBlock.ready_step_spec', 'arguments': ['initial'], 'text': 'EasyBlock.ready_step_spec(initial):\nReturn ready step specified.'}
# {'unique_identifier': 'EasyBlock.source_step_spec', 'arguments': ['initial'], 'text': 'EasyBlock.source_step_spec(initial):\nReturn source step specified.'}
# {'unique_identifier': 'EasyBlock.install_step_spec', 'arguments': ['initial'], 'text': 'EasyBlock.install_step_spec(initial):\nReturn install step specification.'}
# {'unique_identifier': 'EasyBlock.run_all_steps', 'arguments': ['self', 'run_test_cases'], 'text': 'EasyBlock.run_all_steps(self, run_test_cases):\nBuild and install this software.\nrun_test_cases (bool): run tests after building (e.g.: make test)'}
# {'unique_identifier': 'print_dry_run_note', 'arguments': ['loc', 'silent'], 'text': 'print_dry_run_note(loc, silent):\nPrint note on interpreting dry run output.'}
# {'unique_identifier': 'build_and_install_one', 'arguments': ['ecdict', 'init_env'], 'text': 'build_and_install_one(ecdict, init_env):\nBuild the software\n:param ecdict: dictionary contaning parsed easyconfig + metadata\n:param init_env: original environment (used to reset environment)'}
# {'unique_identifier': 'ensure_writable_log_dir', 'arguments': ['log_dir'], 'text': 'ensure_writable_log_dir(log_dir):\nMake sure we can write into the log dir'}
# {'unique_identifier': 'copy_easyblocks_for_reprod', 'arguments': ['easyblock_instances', 'reprod_dir'], 'text': 'copy_easyblocks_for_reprod(easyblock_instances, reprod_dir)'}
# {'unique_identifier': 'reproduce_build', 'arguments': ['app', 'reprod_dir_root'], 'text': "reproduce_build(app, reprod_dir_root):\nCreate reproducibility files (processed easyconfig and easyblocks used) from class instance\n\n:param app: easyblock class instance\n:param reprod_dir_root: root directory in which to create the 'reprod' directory\n\n:return: reprod_dir directory containing reproducibility files"}
# {'unique_identifier': 'get_easyblock_instance', 'arguments': ['ecdict'], 'text': 'get_easyblock_instance(ecdict):\nGet an instance for this easyconfig\n:param ecdict: parsed easyconfig (EasyConfig instance)\n\nreturns an instance of EasyBlock (or subclass thereof)'}
# {'unique_identifier': 'build_easyconfigs', 'arguments': ['easyconfigs', 'output_dir', 'test_results'], 'text': 'build_easyconfigs(easyconfigs, output_dir, test_results):\nBuild the list of easyconfigs.'}
# {'unique_identifier': 'inject_checksums_to_json', 'arguments': ['ecs', 'checksum_type'], 'text': 'inject_checksums_to_json(ecs, checksum_type):\nInject checksums of given type in corresponding json files\n\n:param ecs: list of EasyConfig instances to calculate checksums and inject them into checksums.json\n:param checksum_type: type of checksum to use'}
# {'unique_identifier': 'inject_checksums', 'arguments': ['ecs', 'checksum_type'], 'text': 'inject_checksums(ecs, checksum_type):\nInject checksums of given type in specified easyconfig files\n\n:param ecs: list of EasyConfig instances to inject checksums into corresponding files\n:param checksum_type: type of checksum to use'}
# {'unique_identifier': 'make_list_lines', 'arguments': ['values', 'indent_level'], 'text': 'make_list_lines(values, indent_level):\nMake lines for list of values.'}
# {'unique_identifier': 'to_str', 'arguments': ['s'], 'text': 'to_str(s)'}
# {'unique_identifier': 'make_checksum_lines', 'arguments': ['checksums', 'indent_level'], 'text': 'make_checksum_lines(checksums, indent_level):\nMake lines for list of checksums.'}
# {'unique_identifier': 'ExtensionEasyBlock.extra_options', 'arguments': ['extra_vars'], 'text': 'ExtensionEasyBlock.extra_options(extra_vars):\nExtra easyconfig parameters specific to ExtensionEasyBlock.'}
# {'unique_identifier': 'ExtensionEasyBlock.__init__', 'arguments': ['self'], 'text': 'ExtensionEasyBlock.__init__(self):\nInitialize either as EasyBlock or as Extension.'}
# {'unique_identifier': 'ExtensionEasyBlock._set_start_dir', 'arguments': ['self'], 'text': 'ExtensionEasyBlock._set_start_dir(self):\nSet absolute path of self.start_dir similarly to EasyBlock.guess_start_dir\n\nUses existing value of self.start_dir defaulting to self.ext_dir.\nIf self.ext_dir (path to extracted source) is set, it is used as the base dir for relative paths.\nOtherwise otherwise self.builddir is used as the base.\nWhen neither start_dir nor ext_dir are set or when the computed start_dir does not exist\nthe start dir is not changed.\nThe computed start dir will not end in path separators'}
# {'unique_identifier': 'ExtensionEasyBlock.run', 'arguments': ['self', 'unpack_src'], 'text': 'ExtensionEasyBlock.run(self, unpack_src):\nCommon operations for extensions: unpacking sources, patching, ...'}
# {'unique_identifier': 'ExtensionEasyBlock.sanity_check_step', 'arguments': ['self', 'exts_filter', 'custom_paths', 'custom_commands'], 'text': 'ExtensionEasyBlock.sanity_check_step(self, exts_filter, custom_paths, custom_commands):\nCustom sanity check for extensions, whether installed as stand-alone module or not'}
# {'unique_identifier': 'ExtensionEasyBlock.make_module_extra', 'arguments': ['self', 'extra'], 'text': 'ExtensionEasyBlock.make_module_extra(self, extra):\nAdd custom entries to module.'}
# {'unique_identifier': 'check_value', 'arguments': ['value', 'context'], 'text': 'check_value(value, context):\nCheck whether specified value obtained from a YAML file in specified context represents is valid.\nThe value must be a string (not a float or an int).'}
# {'unique_identifier': 'EasyStack.__init__', 'arguments': ['self'], 'text': 'EasyStack.__init__(self)'}
# {'unique_identifier': 'EasyStack.__str__', 'arguments': ['self'], 'text': 'EasyStack.__str__(self):\nPretty printing of an EasyStack instance'}
# {'unique_identifier': 'EasyStack.get_general_options', 'arguments': ['self'], 'text': 'EasyStack.get_general_options(self):\nReturns general options (flags applicable to all sw (i.e. --robot))'}
# {'unique_identifier': 'SoftwareSpecs.__init__', 'arguments': ['self', 'name', 'version', 'versionsuffix', 'toolchain_version', 'toolchain_name'], 'text': 'SoftwareSpecs.__init__(self, name, version, versionsuffix, toolchain_version, toolchain_name)'}
# {'unique_identifier': 'EasyStackParser.parse', 'arguments': ['filepath'], 'text': 'EasyStackParser.parse(filepath):\nParses YAML file and assigns obtained values to SW config instances as well as general config instance'}
# {'unique_identifier': 'EasyStackParser.parse_by_easyconfigs', 'arguments': ['filepath', 'easyconfigs', 'easybuild_version', 'robot'], 'text': "EasyStackParser.parse_by_easyconfigs(filepath, easyconfigs, easybuild_version, robot):\nParse easystack file with 'easyconfigs' as top-level key."}
# {'unique_identifier': 'parse_easystack', 'arguments': ['filepath'], 'text': 'parse_easystack(filepath):\nParses through easystack file, returns what EC are to be installed together with their options.'}
# {'unique_identifier': 'resolve_exts_filter_template', 'arguments': ['exts_filter', 'ext'], 'text': "resolve_exts_filter_template(exts_filter, ext):\nResolve the exts_filter tuple by replacing the template values using the extension\n:param exts_filter: Tuple of (command, input) using template values (ext_name, ext_version, src)\n:param ext: Instance of Extension or dictionary like with 'name' and optionally 'options', 'version', 'source' keys\n:return: (cmd, input) as a tuple of strings"}
# {'unique_identifier': 'Extension.__init__', 'arguments': ['self', 'mself', 'ext', 'extra_params'], 'text': 'Extension.__init__(self, mself, ext, extra_params):\nConstructor for Extension class\n\n:param mself: parent Easyblock instance\n:param ext: dictionary with extension metadata (name, version, src, patches, options, ...)\n:param extra_params: extra custom easyconfig parameters to take into account for this extension'}
# {'unique_identifier': 'Extension.name', 'arguments': ['self'], 'text': 'Extension.name(self):\nShortcut the get the extension name.'}
# {'unique_identifier': 'Extension.version', 'arguments': ['self'], 'text': 'Extension.version(self):\nShortcut the get the extension version.'}
# {'unique_identifier': 'Extension.prerun', 'arguments': ['self'], 'text': 'Extension.prerun(self):\nStuff to do before installing a extension.'}
# {'unique_identifier': 'Extension.run', 'arguments': ['self'], 'text': 'Extension.run(self):\nActual installation of an extension.'}
# {'unique_identifier': 'Extension.run_async', 'arguments': ['self'], 'text': 'Extension.run_async(self):\nAsynchronous installation of an extension.'}
# {'unique_identifier': 'Extension.postrun', 'arguments': ['self'], 'text': 'Extension.postrun(self):\nStuff to do after installing a extension.'}
# {'unique_identifier': 'Extension.async_cmd_start', 'arguments': ['self', 'cmd', 'inp'], 'text': 'Extension.async_cmd_start(self, cmd, inp):\nStart installation asynchronously using specified command.'}
# {'unique_identifier': 'Extension.async_cmd_check', 'arguments': ['self'], 'text': 'Extension.async_cmd_check(self):\nCheck progress of installation command that was started asynchronously.\n\n:return: True if command completed, False otherwise'}
# {'unique_identifier': 'Extension.required_deps', 'arguments': ['self'], 'text': 'Extension.required_deps(self):\nReturn list of required dependencies for this extension.'}
# {'unique_identifier': 'Extension.toolchain', 'arguments': ['self'], 'text': 'Extension.toolchain(self):\nToolchain used to build this extension.'}
# {'unique_identifier': 'Extension.sanity_check_step', 'arguments': ['self'], 'text': 'Extension.sanity_check_step(self):\nSanity check to run after installing extension'}
# {'unique_identifier': '_eb_check_trailing_whitespace', 'arguments': ['physical_line', 'lines', 'line_number', 'checker_state'], 'text': '_eb_check_trailing_whitespace(physical_line, lines, line_number, checker_state):\nW299\nWarn about trailing whitespace, except for the description and comments.\nThis differs from the standard trailing whitespace check as that\nwill warn for any trailing whitespace.\nThe arguments are explained at\nhttps://pycodestyle.readthedocs.io/en/latest/developer.html#contribute'}
# {'unique_identifier': 'check_easyconfigs_style', 'arguments': ['easyconfigs', 'verbose'], 'text': 'check_easyconfigs_style(easyconfigs, verbose):\nCheck the given list of easyconfigs for style\n:param easyconfigs: list of file paths to easyconfigs\n:param verbose: print our statistics and be verbose about the errors and warning\n:return: the number of warnings and errors'}
# {'unique_identifier': 'cmdline_easyconfigs_style_check', 'arguments': ['ecs'], 'text': "cmdline_easyconfigs_style_check(ecs):\nRun easyconfigs style check of each of the specified easyconfigs, triggered from 'eb' command line\n\n:param ecs: list of easyconfigs to check, could be either file paths or EasyConfig instances\n:return: True when style check passed on all easyconfig files, False otherwise"}
# {'unique_identifier': 'skip_available', 'arguments': ['easyconfigs', 'modtool'], 'text': 'skip_available(easyconfigs, modtool):\nSkip building easyconfigs for existing modules.'}
# {'unique_identifier': 'find_resolved_modules', 'arguments': ['easyconfigs', 'avail_modules', 'modtool', 'retain_all_deps'], 'text': 'find_resolved_modules(easyconfigs, avail_modules, modtool, retain_all_deps):\nFind easyconfigs in 1st argument which can be fully resolved using modules specified in 2nd argument\n\n:param easyconfigs: list of parsed easyconfigs\n:param avail_modules: list of available modules\n:param retain_all_deps: retain all dependencies, regardless of whether modules are available for them or not'}
# {'unique_identifier': 'dep_graph', 'arguments': ['filename', 'specs'], 'text': 'dep_graph(filename, specs):\nCreate a dependency graph for the given easyconfigs.'}
# {'unique_identifier': 'mk_node_name', 'arguments': ['spec'], 'text': 'mk_node_name(spec)'}
# {'unique_identifier': '_dep_graph_dump', 'arguments': ['dgr', 'filename'], 'text': '_dep_graph_dump(dgr, filename):\nDump dependency graph to file, in specified format.'}
# {'unique_identifier': '_dep_graph_gv', 'arguments': ['dottxt', 'filename'], 'text': '_dep_graph_gv(dottxt, filename):\nRender dependency graph to file using graphviz.'}
# {'unique_identifier': 'get_paths_for', 'arguments': ['subdir', 'robot_path'], 'text': 'get_paths_for(subdir, robot_path):\nReturn a list of absolute paths where the specified subdir can be found, determined by the PYTHONPATH'}
# {'unique_identifier': 'alt_easyconfig_paths', 'arguments': ['tmpdir', 'tweaked_ecs', 'from_prs', 'review_pr'], 'text': 'alt_easyconfig_paths(tmpdir, tweaked_ecs, from_prs, review_pr):\nObtain alternative paths for easyconfig files.'}
# {'unique_identifier': 'det_easyconfig_paths', 'arguments': ['orig_paths'], 'text': 'det_easyconfig_paths(orig_paths):\nDetermine paths to easyconfig files.\n:param orig_paths: list of original easyconfig paths\n:return: list of paths to easyconfig files'}
# {'unique_identifier': 'parse_easyconfigs', 'arguments': ['paths', 'validate'], 'text': 'parse_easyconfigs(paths, validate):\nParse easyconfig files\n:param paths: paths to easyconfigs'}
# {'unique_identifier': 'stats_to_str', 'arguments': ['stats', 'isyeb'], 'text': 'stats_to_str(stats, isyeb):\nPretty print build statistics to string.'}
# {'unique_identifier': 'find_related_easyconfigs', 'arguments': ['path', 'ec'], 'text': 'find_related_easyconfigs(path, ec):\nFind related easyconfigs for provided parsed easyconfig in specified path.\n\nA list of easyconfigs for the same software (name) is returned,\nmatching the 1st criterion that yields a non-empty list.\n\nThe following criteria are considered (in this order) next to common software version criterion, i.e.\nexact version match, a major/minor version match, a major version match, or no version match (in that order).\n\n(i)   matching versionsuffix and toolchain name/version\n(ii)  matching versionsuffix and toolchain name (any toolchain version)\n(iii) matching versionsuffix (any toolchain name/version)\n(iv)  matching toolchain name/version (any versionsuffix)\n(v)   matching toolchain name (any versionsuffix, toolchain version)\n(vi)  no extra requirements (any versionsuffix, toolchain name/version)\n\nIf no related easyconfigs with a matching software name are found, an empty list is returned.'}
# {'unique_identifier': 'review_pr', 'arguments': ['paths', 'pr', 'colored', 'branch', 'testing', 'max_ecs', 'filter_ecs'], 'text': 'review_pr(paths, pr, colored, branch, testing, max_ecs, filter_ecs):\nPrint multi-diff overview between specified easyconfigs or PR and specified branch.\n:param pr: pull request number in easybuild-easyconfigs repo to review\n:param paths: path tuples (path, generated) of easyconfigs to review\n:param colored: boolean indicating whether a colored multi-diff should be generated\n:param branch: easybuild-easyconfigs branch to compare with\n:param testing: whether to ignore PR labels (used in test_review_pr)'}
# {'unique_identifier': 'dump_env_easyblock', 'arguments': ['app', 'orig_env', 'ec_path', 'script_path', 'silent'], 'text': 'dump_env_easyblock(app, orig_env, ec_path, script_path, silent)'}
# {'unique_identifier': 'dump_env_script', 'arguments': ['easyconfigs'], 'text': 'dump_env_script(easyconfigs):\nDump source scripts that set up build environment for specified easyconfigs.\n\n:param easyconfigs: list of easyconfigs to generate scripts for'}
# {'unique_identifier': 'categorize_files_by_type', 'arguments': ['paths'], 'text': 'categorize_files_by_type(paths):\nSplits list of filepaths into a 4 separate lists: easyconfigs, files to delete, patch files and\nfiles with extension .py'}
# {'unique_identifier': 'check_sha256_checksums', 'arguments': ['ecs', 'whitelist'], 'text': 'check_sha256_checksums(ecs, whitelist):\nCheck whether all provided (parsed) easyconfigs have SHA256 checksums for sources & patches.\n\n:param whitelist: list of regex patterns on easyconfig filenames; check is skipped for matching easyconfigs\n:return: list of strings describing checksum issues (missing checksums, wrong checksum type, etc.)'}
# {'unique_identifier': 'run_contrib_checks', 'arguments': ['ecs'], 'text': 'run_contrib_checks(ecs):\nRun contribution check on specified easyconfigs.'}
# {'unique_identifier': 'print_result', 'arguments': ['checks_passed', 'label'], 'text': 'print_result(checks_passed, label):\nHelper function to print result of last group of checks.'}
# {'unique_identifier': 'avail_easyblocks', 'arguments': [], 'text': 'avail_easyblocks():\nReturn a list of all available easyblocks.'}
# {'unique_identifier': 'det_copy_ec_specs', 'arguments': ['orig_paths', 'from_pr'], 'text': 'det_copy_ec_specs(orig_paths, from_pr):\nDetermine list of paths + target directory for --copy-ec.'}
# {'unique_identifier': '_get_arch_constant', 'arguments': [], 'text': '_get_arch_constant():\nGet value for ARCH constant.'}
# {'unique_identifier': 'as_hashable', 'arguments': ['dict_value'], 'text': 'as_hashable(dict_value):\nHelper function, convert dict value to hashable equivalent via tuples.'}
# {'unique_identifier': 'check_element_types', 'arguments': ['elems', 'allowed_types'], 'text': 'check_element_types(elems, allowed_types):\nCheck whether types of elements of specified (iterable) value are as expected.\n\n:param elems: iterable value (list or dict) of elements\n:param allowed_types: allowed types per element; either a simple list, or a dict of allowed_types by element name'}
# {'unique_identifier': 'check_key_types', 'arguments': ['val', 'allowed_types'], 'text': 'check_key_types(val, allowed_types):\nCheck whether type of keys for specific dict value are as expected.'}
# {'unique_identifier': 'check_known_keys', 'arguments': ['val', 'allowed_keys'], 'text': 'check_known_keys(val, allowed_keys):\nCheck whether all keys for specified dict value are known keys.'}
# {'unique_identifier': 'check_required_keys', 'arguments': ['val', 'required_keys'], 'text': 'check_required_keys(val, required_keys):\nCheck whether all required keys are present in the specified dict value.'}
# {'unique_identifier': 'is_value_of_type', 'arguments': ['value', 'expected_type'], 'text': 'is_value_of_type(value, expected_type):\nCheck whether specified value matches a particular very specific (non-trivial) type,\nwhich is specified by means of a 2-tuple: (parent type, tuple with additional type requirements).\n\n:param value: value to check the type of\n:param expected_type: type of value to check against'}
# {'unique_identifier': 'check_type_of_param_value', 'arguments': ['key', 'val', 'auto_convert'], 'text': 'check_type_of_param_value(key, val, auto_convert):\nCheck value type of specified easyconfig parameter.\n\n:param key: name of easyconfig parameter\n:param val: easyconfig parameter value, of which type should be checked\n:param auto_convert: try to automatically convert to expected value type if required'}
# {'unique_identifier': 'convert_value_type', 'arguments': ['val', 'typ'], 'text': 'convert_value_type(val, typ):\nTry to convert type of provided value to specific type.\n\n:param val: value to convert type of\n:param typ: target type'}
# ...
# {'unique_identifier': 'ToolchainVersionOperator.__init__', 'arguments': ['self', 'tcversop_str'], 'text': 'ToolchainVersionOperator.__init__(self, tcversop_str):\nInitialise VersionOperator instance.\n:param tcversop_str: intialise with toolchain version operator string'}
# {'unique_identifier': 'ToolchainVersionOperator.__str__', 'arguments': ['self'], 'text': 'ToolchainVersionOperator.__str__(self):\nReturn string representation of this instance'}
# {'unique_identifier': 'ToolchainVersionOperator.__hash__', 'arguments': ['self'], 'text': 'ToolchainVersionOperator.__hash__(self):\nReturn hash for this object.'}
# {'unique_identifier': 'ToolchainVersionOperator._get_all_toolchain_names', 'arguments': ['self', 'search_string'], 'text': 'ToolchainVersionOperator._get_all_toolchain_names(self, search_string):\nInitialise each search_toolchain request, save in module constant TOOLCHAIN_NAMES.\n:param search_string: passed to search_toolchain function.'}
# {'unique_identifier': 'ToolchainVersionOperator.is_valid', 'arguments': ['self'], 'text': 'ToolchainVersionOperator.is_valid(self):\nCheck if this is a valid ToolchainVersionOperator'}
# {'unique_identifier': 'ToolchainVersionOperator.set', 'arguments': ['self', 'tcversop_str'], 'text': "ToolchainVersionOperator.set(self, tcversop_str):\nParse argument as toolchain version string, and set attributes.\nReturns None in case of failure (e.g. if supplied string doesn't parse), True in case of success."}
# {'unique_identifier': 'ToolchainVersionOperator.versop_regex', 'arguments': ['self'], 'text': "ToolchainVersionOperator.versop_regex(self):\nCreate the regular expression for toolchain support of format ^<toolchain> <versop_expr>$ ,\nwith <toolchain> the name of one of the supported toolchains and <versop_expr> in '<operator> <version>' syntax"}
# {'unique_identifier': 'ToolchainVersionOperator.parse_versop_str', 'arguments': ['self', 'tcversop_str'], 'text': 'ToolchainVersionOperator.parse_versop_str(self, tcversop_str):\nIf argument matches a toolchain versop, return dict with toolchain name and version, and optionally operator.\nOtherwise, return None.'}
# {'unique_identifier': 'ToolchainVersionOperator._boundary_check', 'arguments': ['self', 'other'], 'text': 'ToolchainVersionOperator._boundary_check(self, other):\nReturn the boundary checks via testing: is self in other, and is other in self\n:param other: a ToolchainVersionOperator instance'}
# {'unique_identifier': 'ToolchainVersionOperator.test', 'arguments': ['self', 'name', 'version'], 'text': 'ToolchainVersionOperator.test(self, name, version):\nCheck if a toolchain with name name and version version would fit\n    in this ToolchainVersionOperator\n:param name: toolchain name\n:param version: a version string or EasyVersion instance'}
# {'unique_identifier': 'ToolchainVersionOperator.as_dict', 'arguments': ['self'], 'text': 'ToolchainVersionOperator.as_dict(self):\nReturn toolchain version operator as a dictionary with name/version keys.\nReturns None if translation to a dictionary is not possible (e.g. non-equals operator, missing version, ...).'}
# {'unique_identifier': 'OrderedVersionOperators.__init__', 'arguments': ['self'], 'text': 'OrderedVersionOperators.__init__(self):\nInitialise the list of version operators as an empty list.'}
# {'unique_identifier': 'OrderedVersionOperators.__str__', 'arguments': ['self'], 'text': 'OrderedVersionOperators.__str__(self):\nPrint the list and map'}
# {'unique_identifier': 'OrderedVersionOperators.add', 'arguments': ['self', 'versop_new', 'data', 'update'], 'text': 'OrderedVersionOperators.add(self, versop_new, data, update):\nTry to add argument as VersionOperator instance to current list of version operators.\nMake sure there is no conflict with existing versops, and that the ordering is maintained.\nAfter add, versop_new is in the OrderedVersionOperators. If the same versop_new was already in it,\nit will update the data (if not None) (and not raise an error)\n\n:param versop_new: VersionOperator instance (or will be converted into one if type string)\n:param data: additional data for supplied version operator to be stored\n:param update: if versop_new already exist and has data set, try to update the existing data with the new data;\n               instead of overriding the existing data with the new data (method used for updating is .update)'}
# {'unique_identifier': 'OrderedVersionOperators._add_data', 'arguments': ['self', 'versop_new', 'data', 'update'], 'text': 'OrderedVersionOperators._add_data(self, versop_new, data, update):\nAdd the data to the datamap, use the string representation of the operator as key'}
# {'unique_identifier': 'OrderedVersionOperators.get_data', 'arguments': ['self', 'versop'], 'text': 'OrderedVersionOperators.get_data(self, versop):\nReturn the data for versop from datamap'}
# {'unique_identifier': 'Dependency.__init__', 'arguments': ['self', 'obj', 'name'], 'text': 'Dependency.__init__(self, obj, name):\nConvert pass object to a dependency, use specified name if provided.'}
# {'unique_identifier': 'Dependency._from_string', 'arguments': ['self', 'txt'], 'text': "Dependency._from_string(self, txt):\nConvert from string\nversop_str;tc_versop_str -> {'versop': versop, 'tc_versop': tc_versop}"}
# {'unique_identifier': 'Dependency.__str__', 'arguments': ['self'], 'text': 'Dependency.__str__(self):\nReturn string'}
# {'unique_identifier': 'Dependency.name', 'arguments': ['self'], 'text': 'Dependency.name(self):\nGet dependency name.'}
# {'unique_identifier': 'Dependency.version', 'arguments': ['self'], 'text': 'Dependency.version(self):\nGet dependency version.'}
# {'unique_identifier': 'Dependency.versionsuffix', 'arguments': ['self'], 'text': 'Dependency.versionsuffix(self):\nGet dependency versionsuffix (if any).'}
# {'unique_identifier': 'Dependency.toolchain', 'arguments': ['self'], 'text': 'Dependency.toolchain(self):\nGet toolchain spec for dependency (if any).'}
# {'unique_identifier': 'FormatTwoZero.validate', 'arguments': ['self'], 'text': 'FormatTwoZero.validate(self):\nFormat validation'}
# {'unique_identifier': 'FormatTwoZero._check_docstring', 'arguments': ['self'], 'text': 'FormatTwoZero._check_docstring(self):\nVerify docstring.\nfield :author: people who contributed to the easyconfig\nfield @maintainer: people who can be contacted in case of problems'}
# {'unique_identifier': 'FormatTwoZero.get_config_dict', 'arguments': ['self'], 'text': 'FormatTwoZero.get_config_dict(self):\nReturn the best matching easyconfig dict'}
# {'unique_identifier': 'FormatTwoZero.extract_comments', 'arguments': ['self', 'rawtxt'], 'text': 'FormatTwoZero.extract_comments(self, rawtxt):\nExtract comments from raw content.'}
# {'unique_identifier': 'get_format_version', 'arguments': ['txt'], 'text': 'get_format_version(txt):\nGet the easyconfig format version as EasyVersion instance.'}
# {'unique_identifier': 'NestedDict.__init__', 'arguments': ['self', 'parent', 'depth'], 'text': 'NestedDict.__init__(self, parent, depth):\nInitialise NestedDict instance'}
# {'unique_identifier': 'NestedDict.get_nested_dict', 'arguments': ['self'], 'text': 'NestedDict.get_nested_dict(self):\nReturn an instance of NestedDict with this instance as parent'}
# {'unique_identifier': 'NestedDict.copy', 'arguments': ['self'], 'text': 'NestedDict.copy(self):\nReturn a copy. Any relation between key and value are deepcopied away.'}
# {'unique_identifier': 'TopNestedDict.__init__', 'arguments': ['self', 'parent', 'depth'], 'text': 'TopNestedDict.__init__(self, parent, depth):\nInitialise TopNestedDict instance'}
# {'unique_identifier': 'Squashed.__init__', 'arguments': ['self'], 'text': 'Squashed.__init__(self):\nInitialise Squashed instance'}
# {'unique_identifier': 'Squashed.add_toolchain', 'arguments': ['self', 'squashed'], 'text': 'Squashed.add_toolchain(self, squashed):\nAdd squashed instance from a toolchain section\n:param squashed: a Squashed instance'}
# {'unique_identifier': 'Squashed.add_version', 'arguments': ['self', 'section', 'squashed'], 'text': 'Squashed.add_version(self, section, squashed):\nAdd squashed instance from version section\n:param section: the version section versionoperator instance\n:param squashed: a Squashed instance'}
# {'unique_identifier': 'Squashed.final', 'arguments': ['self'], 'text': 'Squashed.final(self):\nFinal squashing of version and toolchainversion operators and return the result'}
# {'unique_identifier': 'EBConfigObj.__init__', 'arguments': ['self', 'configobj'], 'text': 'EBConfigObj.__init__(self, configobj):\nInitialise EBConfigObj instance\n:param configobj: ConfigObj instance'}
# {'unique_identifier': 'EBConfigObj._init_sections', 'arguments': ['self'], 'text': "EBConfigObj._init_sections(self):\nInitialise self.sections. Make sure 'default' and 'supported' sections exist."}
# {'unique_identifier': 'EBConfigObj.parse_sections', 'arguments': ['self', 'toparse', 'current'], 'text': 'EBConfigObj.parse_sections(self, toparse, current):\nParse Section instance; convert all supported sections, keys and values to their respective representations\n\nReturns a dict of (nested) Sections\n\n:param toparse: a Section (or ConfigObj) instance, basically a dict of (unparsed) sections\n:param current: the current NestedDict'}
# {'unique_identifier': 'EBConfigObj.parse', 'arguments': ['self', 'configobj'], 'text': 'EBConfigObj.parse(self, configobj):\nParse configobj using using recursive parse_sections.\nThen split off the default and supported sections.\n\n:param configobj: ConfigObj instance'}
# {'unique_identifier': 'EBConfigObj.squash', 'arguments': ['self', 'version', 'tcname', 'tcversion'], 'text': 'EBConfigObj.squash(self, version, tcname, tcversion):\nProject the multidimensional easyconfig to single easyconfig\nIt (tries to) detect conflicts in the easyconfig.\n\n:param version: version to keep\n:param tcname: toolchain name to keep\n:param tcversion: toolchain version to keep'}
# {'unique_identifier': 'EBConfigObj._squash', 'arguments': ['self', 'vt_tuple', 'processed', 'sanity'], 'text': 'EBConfigObj._squash(self, vt_tuple, processed, sanity):\nProject the multidimensional easyconfig (or subsection thereof) to single easyconfig\nReturns Squashed instance for the processed block.\n:param vt_tuple: tuple with version (version to keep), tcname (toolchain name to keep) and\n                    tcversion (toolchain version to keep)\n:param processed: easyconfig (Top)NestedDict\n:param sanity: dictionary to keep track of section markers and detect conflicts'}
# {'unique_identifier': 'EBConfigObj._squash_netsed_dict', 'arguments': ['self', 'key', 'nested_dict', 'squashed', 'sanity', 'vt_tuple'], 'text': 'EBConfigObj._squash_netsed_dict(self, key, nested_dict, squashed, sanity, vt_tuple):\nSquash NestedDict instance, returns dict with already squashed data\n    from possible higher sections\n:param key: section key\n:param nested_dict: the nested_dict instance\n:param squashed: Squashed instance\n:param sanity: the sanity dict\n:param vt_tuple: version, tc_name, tc_version tuple'}
# {'unique_identifier': 'EBConfigObj._squash_versop', 'arguments': ['self', 'key', 'value', 'squashed', 'sanity', 'vt_tuple'], 'text': 'EBConfigObj._squash_versop(self, key, value, squashed, sanity, vt_tuple):\nSquash VERSION_OPERATOR_VALUE_TYPES value\n    return None or new Squashed instance\n:param key: section key\n:param nested_dict: the nested_dict instance\n:param squashed: Squashed instance\n:param sanity: the sanity dict\n:param vt_tuple: version, tc_name, tc_version tuple'}
# {'unique_identifier': 'EBConfigObj.get_version_toolchain', 'arguments': ['self', 'version', 'tcname', 'tcversion'], 'text': 'EBConfigObj.get_version_toolchain(self, version, tcname, tcversion):\nReturn tuple of version, toolchainname and toolchainversion (possibly using defaults).'}
# {'unique_identifier': 'EBConfigObj.get_specs_for', 'arguments': ['self', 'version', 'tcname', 'tcversion'], 'text': 'EBConfigObj.get_specs_for(self, version, tcname, tcversion):\nReturn dictionary with specifications listed in sections applicable for specified info.'}
# {'unique_identifier': 'EasyConfigFormat.__init__', 'arguments': ['self'], 'text': 'EasyConfigFormat.__init__(self):\nInitialise the EasyConfigFormat class'}
# {'unique_identifier': 'EasyConfigFormat.comments', 'arguments': ['self'], 'text': 'EasyConfigFormat.comments(self):\nReturn comments in easyconfig file'}
# {'unique_identifier': 'EasyConfigFormat.set_specifications', 'arguments': ['self', 'specs'], 'text': 'EasyConfigFormat.set_specifications(self, specs):\nSet specifications.'}
# {'unique_identifier': 'EasyConfigFormat.get_config_dict', 'arguments': ['self'], 'text': 'EasyConfigFormat.get_config_dict(self):\nReturns a single easyconfig dictionary.'}
# {'unique_identifier': 'EasyConfigFormat.validate', 'arguments': ['self'], 'text': 'EasyConfigFormat.validate(self):\nVerify the easyconfig format'}
# {'unique_identifier': 'EasyConfigFormat.parse', 'arguments': ['self', 'txt'], 'text': 'EasyConfigFormat.parse(self, txt):\nParse the txt according to this format. This is highly version specific'}
# {'unique_identifier': 'EasyConfigFormat.dump', 'arguments': ['self', 'ecfg', 'default_values', 'templ_const', 'templ_val', 'toolchain_hierarchy'], 'text': 'EasyConfigFormat.dump(self, ecfg, default_values, templ_const, templ_val, toolchain_hierarchy):\nDump easyconfig according to this format. This is highly version specific'}
# {'unique_identifier': 'EasyConfigFormat.extract_comments', 'arguments': ['self', 'rawtxt'], 'text': 'EasyConfigFormat.extract_comments(self, rawtxt):\nExtract comments from raw content.'}
# {'unique_identifier': 'get_format_version_classes', 'arguments': ['version'], 'text': 'get_format_version_classes(version):\nReturn the (usable) subclasses from EasyConfigFormat that have a matching version.'}
# {'unique_identifier': 'yaml_join', 'arguments': ['loader', 'node'], 'text': 'yaml_join(loader, node):\ndefines custom YAML join function.\nsee http://stackoverflow.com/questions/5484016/\n    how-can-i-do-string-concatenation-or-string-replacement-in-yaml/23212524#23212524\n:param loader: the YAML Loader\n:param node: the YAML (sequence) node'}
# {'unique_identifier': 'FormatYeb.__init__', 'arguments': ['self'], 'text': 'FormatYeb.__init__(self):\nFormatYeb constructor'}
# {'unique_identifier': 'FormatYeb.validate', 'arguments': ['self'], 'text': 'FormatYeb.validate(self):\nFormat validation'}
# {'unique_identifier': 'FormatYeb.get_config_dict', 'arguments': ['self'], 'text': 'FormatYeb.get_config_dict(self):\nReturn parsed easyconfig as a dictionary, based on specified arguments.'}
# {'unique_identifier': 'FormatYeb.parse', 'arguments': ['self', 'txt'], 'text': 'FormatYeb.parse(self, txt):\nProcess YAML file'}
# {'unique_identifier': 'FormatYeb._inject_constants_dict', 'arguments': ['self', 'txt'], 'text': 'FormatYeb._inject_constants_dict(self, txt):\nInject constants so they are resolved when actually parsing the YAML text.'}
# {'unique_identifier': 'FormatYeb.dump', 'arguments': ['self', 'ecfg', 'default_values', 'templ_const', 'templ_val', 'toolchain_hierarchy'], 'text': 'FormatYeb.dump(self, ecfg, default_values, templ_const, templ_val, toolchain_hierarchy):\nDump parsed easyconfig in .yeb format'}
# {'unique_identifier': 'FormatYeb.extract_comments', 'arguments': ['self', 'txt'], 'text': 'FormatYeb.extract_comments(self, txt):\nExtract comments from easyconfig file'}
# {'unique_identifier': 'is_yeb_format', 'arguments': ['filename', 'rawcontent'], 'text': 'is_yeb_format(filename, rawcontent):\nDetermine whether easyconfig is in .yeb format.\nIf filename is None, rawcontent will be used to check the format.'}
# {'unique_identifier': 'quote_yaml_special_chars', 'arguments': ['val'], 'text': 'quote_yaml_special_chars(val):\nSingle-quote values that contain special characters, specifically to be used in YAML context (.yeb files)\nSingle quotes inside the string are escaped by doubling them.\n(see: http://symfony.com/doc/current/components/yaml/yaml_format.html#strings)'}

# %%
db_name = "docstring_db"
with VectorDBTextAnalyzerBase(db_name) as vdb:
    vdb.create_db(cleanup=True)
    vdb.populate_db(docstrings)

# %%
query = "function for naming easyconfig files"
with VectorDBTextAnalyzerBase(db_name) as vdb:
    response = vdb.search(query=query)
    vdb.print_search_results(query=query, response=response)
# Out:
# _______QUERY_______
# function for naming easyconfig files
# -------------------
# _______RESULTS_______
# -------------------
# unique_identifier: EasyConfig.name
# text: EasyConfig.name(self):
# returns name
# Distance: 0.18315637111663818
# -------------------
# unique_identifier: EasyConfig.filename
# text: EasyConfig.filename(self):
# Determine correct filename for this easyconfig file.
# Distance: 0.1854965090751648
# -------------------
# unique_identifier: robot_find_easyconfig
# text: robot_find_easyconfig(name, version):
# Find an easyconfig for module in path, returns (absolute) path to easyconfig file (or None, if none is found).
# Distance: 0.21934425830841064

# %%
query = "composing path to easyconfig given software name"
with VectorDBTextAnalyzerBase(db_name) as vdb:
    response = vdb.search(query=query, limit=3)
    vdb.print_search_results(query=query, response=response)
# Out:
# _______QUERY_______
# composing path to easyconfig given software name
# -------------------
# _______RESULTS_______
# -------------------
# unique_identifier: EasyConfig.name
# text: EasyConfig.name(self):
# returns name
# Distance: 0.19211065769195557
# -------------------
# unique_identifier: robot_find_easyconfig
# text: robot_find_easyconfig(name, version):
# Find an easyconfig for module in path, returns (absolute) path to easyconfig file (or None, if none is found).
# Distance: 0.19965869188308716
# -------------------
# unique_identifier: EasyConfig.filename
# text: EasyConfig.filename(self):
# Determine correct filename for this easyconfig file.
# Distance: 0.2114248275756836

# %%
query = "return easyblock class from string"
with VectorDBTextAnalyzerBase(db_name) as vdb:
    response = vdb.search(query=query, limit=3)
    vdb.print_search_results(query=query, response=response)
# Out:
# _______QUERY_______
# return easyblock class from string
# -------------------
# _______RESULTS_______
# -------------------
# unique_identifier: get_easyblock_class
# text: get_easyblock_class(easyblock, name, error_on_failed_import, error_on_missing_easyblock):
# Get class for a particular easyblock (or use default)
# Distance: 0.1510791778564453
# -------------------
# unique_identifier: EasyBlock.name
# text: EasyBlock.name(self):
# Shortcut the get the module name.
# Distance: 0.2112443447113037
# -------------------
# unique_identifier: get_easyblock_instance
# text: get_easyblock_instance(ecdict):
# Get an instance for this easyconfig
# :param ecdict: parsed easyconfig (EasyConfig instance)
#
# returns an instance of EasyBlock (or subclass thereof)
# Distance: 0.21596300601959229

# %%
query = "draw a dependency graph"
with VectorDBTextAnalyzerBase(db_name) as vdb:
    response = vdb.search(query=query, limit=3)
    vdb.print_search_results(query=query, response=response)
# Out:
# _______QUERY_______
# draw a dependency graph
# -------------------
# _______RESULTS_______
# -------------------
# unique_identifier: _dep_graph_gv
# text: _dep_graph_gv(dottxt, filename):
# Render dependency graph to file using graphviz.
# Distance: 0.20450878143310547
# -------------------
# unique_identifier: _dep_graph_dump
# text: _dep_graph_dump(dgr, filename):
# Dump dependency graph to file, in specified format.
# Distance: 0.22117376327514648
# -------------------
# unique_identifier: dep_graph
# text: dep_graph(filename, specs):
# Create a dependency graph for the given easyconfigs.
# Distance: 0.22357124090194702

# %%
query = "steps to take after installing extension"
with VectorDBTextAnalyzerBase(db_name) as vdb:
    response = vdb.search(query=query, limit=3)
    vdb.print_search_results(query=query, response=response)
# Out:
# _______QUERY_______
# steps to take after installing extension
# -------------------
# _______RESULTS_______
# -------------------
# unique_identifier: Extension.postrun
# text: Extension.postrun(self):
# Stuff to do after installing a extension.
# Distance: 0.17652273178100586
# -------------------
# unique_identifier: Extension.sanity_check_step
# text: Extension.sanity_check_step(self):
# Sanity check to run after installing extension
# Distance: 0.2012847661972046
# -------------------
# unique_identifier: Extension.prerun
# text: Extension.prerun(self):
# Stuff to do before installing a extension.
# Distance: 0.213120698928833

# %%
query = "gather a list of patches to apply to the source code"
with VectorDBTextAnalyzerBase(db_name) as vdb:
    response = vdb.search(query=query, limit=3)
    vdb.print_search_results(query=query, response=response)
# Out:
# _______QUERY_______
# gather a list of patches to apply to the source code
# -------------------
# _______RESULTS_______
# -------------------
# unique_identifier: EasyBlock.apply_post_install_patches
# text: EasyBlock.apply_post_install_patches(self, patches):
# Apply post-install patch files that are specified via the 'postinstallpatches' easyconfig parameter.
# Distance: 0.2198238968849182
# -------------------
# unique_identifier: EasyBlock.patch_step
# text: EasyBlock.patch_step(self, beginpath, patches):
# Apply the patches
# Distance: 0.22515273094177246
# -------------------
# unique_identifier: EasyBlock.fetch_patches
# text: EasyBlock.fetch_patches(self, patch_specs, extension, checksums):
# Add a list of patches.
# All patches will be checked if a file exists (or can be located)
# Distance: 0.22562217712402344
